# %% [markdown]
# # Week 1 Problem Set
# ## \$50K and two tactics
#
# **Goal of this problem set:** make sure you can open, modify, and run a Colab notebook.
#
# There are two coding tasks (modify two numbers and re-run) and one short written question.
#
# **A note about this assignment.** This is a setup task — its purpose is to confirm that your Colab environment works and that you can run a cell, change a number, and write a short answer. The first *real* problem set, with substantive analysis and a written memo, starts in Week 2. If this feels easy, that's intentional. If something breaks (Colab won't open, a cell won't run, you can't find the Run button), bring it to office hours **before Week 2**.

# %% [markdown]
# ### Before you start
#
# **Save your own copy first.** Go to **File → Save a copy in Drive**. A new tab opens with your own copy — work in that tab. Edits you make to the original are not saved.
#
# **The data loads itself.** There is nothing to download or upload. The setup cell below pulls the data straight from the course repository; you just need to be online.
#
# Stuck? See the Colab troubleshooting guide on the syllabus.

# %% [markdown]
# ## Setup
#
# Run the cell below to set up the original numbers from the case.

# %%
budget = 50000

# Mailer (Option A)
mailer_fixed_cost = 0
mailer_marginal_cost = 0.50  # dollars per household

# Digital ad (Option B)
digital_fixed_cost = 30000
digital_marginal_cost = 0.05  # dollars per impression

# %%
# Reproduce the mailer and digital comparisons from class.
mailer_households = (budget - mailer_fixed_cost) / mailer_marginal_cost
mailer_avg_cost = budget / mailer_households

digital_impressions = (budget - digital_fixed_cost) / digital_marginal_cost
digital_avg_cost = budget / digital_impressions

print('Mailer:  households reached =', mailer_households,
      '  average cost per household = $', round(mailer_avg_cost, 4))
print('Digital: impressions served =', digital_impressions,
      '  average cost per impression = $', round(digital_avg_cost, 4))

# %% [markdown]
# **Before you move on:** look at the line `digital_avg_cost = budget / digital_impressions` in the cell above. If `digital_fixed_cost` were \$0 instead of \$30,000, would `digital_avg_cost` equal, exceed, or fall below `digital_marginal_cost`? Why?
#
# Write your answer in 1–2 sentences in the cell below.

# %% [markdown]
# **Your answer:**
#
# *Replace this text with your answer.*

# %% [markdown]
# ## Task 1 — Change the mailer's marginal cost
#
# Suppose your mail vendor renegotiates and the marginal cost falls from \$0.50 to **\$0.35** per household.
#
# Edit the cell below to set `mailer_marginal_cost = 0.35`, then re-run it and the cell after it.

# %%
# TODO: change this number
mailer_marginal_cost = 0.50

new_mailer_households = (budget - mailer_fixed_cost) / mailer_marginal_cost
new_mailer_avg_cost = budget / new_mailer_households

print('New mailer households reached:', new_mailer_households)
print('New mailer average cost per household: $', round(new_mailer_avg_cost, 4))

# %% [markdown]
# ## Task 2 — Change the digital ad's production cost
#
# Suppose your digital consultant offers to use a stock template for the ad and cuts the production cost from \$30,000 to **\$5,000**.
#
# Edit the cell below to set `digital_fixed_cost = 5000`, then re-run it.

# %%
# TODO: change this number
digital_fixed_cost = 30000

new_digital_impressions = (budget - digital_fixed_cost) / digital_marginal_cost
new_digital_avg_cost = budget / new_digital_impressions

print('New digital impressions delivered:', new_digital_impressions)
print('New digital average cost per impression: $', round(new_digital_avg_cost, 4))

# %% [markdown]
# ## Task 3 — A third tactic
#
# A field organizer offers door-to-door canvassing. The details:
#
# - Fixed cost: \$8,000 (training and printed walk lists)
# - Marginal cost: \$20 per completed conversation
# - Budget: \$50,000 (same as above)
#
# In the empty code cell below, write the code yourself. Specifically:
#
# 1. Create three variables: `canvass_fixed_cost`, `canvass_marginal_cost`, and `budget` (use 50000).
# 2. Compute `canvass_conversations` — the number of conversations you can afford. Use the same arithmetic pattern as the mailer and digital cells above: `(budget - fixed_cost) / marginal_cost`.
# 3. Compute `canvass_avg_cost` — the average cost per conversation: `budget / canvass_conversations`.
# 4. Print both numbers.
#
# *Check: you should get 2,100 conversations and an average cost of about \$23.81.*

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Task 4 — Short written response
#
# In the cell below (a markdown cell — double-click to edit), answer in **3–6 sentences**:
#
# > If the production cost of the digital ad were \$5,000 instead of \$30,000, how would your recommendation change? Why?
#
# In your answer, use the words **fixed cost**, **marginal cost**, and **average cost**. Be specific about what numbers changed and what they mean for the decision.
#
# You do **not** need to commit to one tactic — but if you don't, explain what other information you'd want to make the call.

# %% [markdown]
# **Your answer:**
#
# *Replace this text with your answer.*

# %% [markdown]
# ---
#
# ## You're done.
#
# If you got stuck on *anything* — opening Colab, running a cell, finding the file — bring it to office hours **before Week 2**. You'll need this working next week.

# %% [markdown]
# ---
#
# ## Before you submit
#
# 1. **Runtime → Restart session and run all.** Do this *after* you have finished every task and written your memo. It clears every variable and runs the notebook from top to bottom, in order, so the version you hand in is one that actually works start to finish.
# 2. **Check that every cell actually ran.** Scroll from the top. Every code cell should show a number in its left margin and its output below it. If the run stopped at a cell with an error, that is a cell you have not finished — fix it, then restart and run all again.
# 3. **File → Print → Save as PDF.**
# 4. **Open the PDF and read it before you upload.** The PDF will look complete even when it isn't — every heading and prompt prints whether or not the code ran. What matters is the **output**: under each code cell you should see a table, a number, or a plot. A red error box, or `In [ ]` with nothing beneath it, means that part did not run and will be graded as missing. Also check that your memo printed in full and that no plot is cut off at a page break.
# 5. Upload the PDF to Canvas.
